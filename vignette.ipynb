# %%
pip install stock-info-easy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stock_info_easy import stock_info_easy

# %%
help(stock_info_easy)
# Out:
# Help on module stock_info_easy.stock_info_easy in stock_info_easy:
#
# NAME
#     stock_info_easy.stock_info_easy
#
# DESCRIPTION
#     Python package that allows users to get stock information easily simply by inserting the names of their interested companies.
#     This module uses the yfinance wraper, an already existing Yahoo Finance API wraper to fetch the stock data.
#     In the previous API wraper, it is difficult to fetch finance data by company names as their stock data are available via companys' abbreviated symbols.
#     This package aims to proivde prime stock information in a user-friendly way: by simply adding company names.
#     Interactive visuals and audio files will be generated to help non-finance people understand the key numerical stock values.
#
# FUNCTIONS
#     create_pricelist(close_prices, windown_size=30)
#         This function extracts historical stock data for the queried time interval, and
# ...

# %%
help(stock_info_easy.get_hist_data)
# Out:
# Help on function get_hist_data in module stock_info_easy.stock_info_easy:
#
# get_hist_data(comp_names, start_date='01/04/2022', end_date='2022-12-19', interval='1d')
#      Get historical stock data for the customized time frame.
#      Data to be fetched are Open, High, Low, Close, Adj Close, Volume, Company Name, and Company Full Name.
#      - High, Low: refer to the maximum and minimum prices in a given time period.
#      - Open: refers to the price at which a stock started trading when the opening bell rang.
#      - Close: refers to the price of an individual stock when the stock exchange closed shop for the day.
#      - Adj Close: amended closing price to reflect that stock's value after accounting for any corporate actions.
#      - Volume: the amount of shares or contracts traded in an asset/ security over a period of time (a trading day).
#
#      Parameters
#      ----------
#      comp_names: tuple
#          company names
#      start_date: str
# ...

# %%
help(stock_info_easy.get_closing_price_viz)
# Out:
# Help on function get_closing_price_viz in module stock_info_easy.stock_info_easy:
#
# get_closing_price_viz(company_list, comp_names)
#     Visualizing the closing price for each company.
#
#     Parameters
#     ----------
#     company_list: list
#         Using the company list from the get_hist_data function.
#     comp_names: tuple
#         Using the company names from the get_hist_data function.
#
#     Return
#     -------
#     Plots of closing prices for each input company.

# %%
help(stock_info_easy.get_daily_return_viz)
# Out:
# Help on function get_daily_return_viz in module stock_info_easy.stock_info_easy:
#
# get_daily_return_viz(company_list, company_names)
#     Visualizing daily return for each input company.
#
#     Parameters
#     ----------
#     company_list: list
#         Using the company list from the get_hist_data function.
#     comp_names: tuple
#         Using the company names from the get_hist_data function.
#
#     Return
#     -------
#     Plots of daily returns for each input company.

# %%
help(stock_info_easy.predict_future_price)
# Out:
# Help on function predict_future_price in module stock_info_easy.stock_info_easy:
#
# predict_future_price(data_list, comp_names_abbr, windown_size=30, predict_window_size=10, predict=True)
#     Predict future price.
#
#     Parameters
#     ----------
#     data_list: pandas.core.frame.DataFrame
#
#     windown_size: int
#         Window size determines the size of the sliding window.
#
#     predict_window_size: int
#
#     predict: bool
#         Whether to predict or not; True/ False
#     -------
#     >

# %%
help(stock_info_easy.generate_audio)
# Out:
# Help on function generate_audio in module stock_info_easy.stock_info_easy:
#
# generate_audio(comp_names_abbr, audio_filename='default1.mp3')
#     Generate an audio file that provides information on company's full name, sector/ industry, and daily PE ratio.
#
#     Parameters
#     ----------
#     comp_names_abbr: list
#         A list of abbreviated company names (symbols).
#
#     audio_filename: str
#         Name of the audiofile.
#
#     Return
#     -------
#     default1.mp3  #an mp3 audio file

# %%
data_list, comp_names_abbr, company_list, comp_names = \
stock_info_easy.get_hist_data((['amazon', 'apple', 'google', 'microsoft']), \
                              start_date="01/04/2022")

# %%
data_list
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2022-01-04  170.438004  171.399994  166.349503  167.522003  167.522003
# 2022-01-05  166.882996  167.126495  164.356995  164.356995  164.356995
# 2022-01-06  163.450500  164.800003  161.936996  163.253998  163.253998
# 2022-01-07  163.839005  165.243500  162.031006  162.554001  162.554001
# 2022-01-10  160.585495  161.661499  156.304504  161.485992  161.485992
# ...                ...         ...         ...         ...         ...
# 2022-12-13  261.690002  263.920013  253.070007  256.920013  256.920013
# 2022-12-14  257.130005  262.589996  254.309998  257.220001  257.220001
# 2022-12-15  253.720001  254.199997  247.339996  249.009995  249.009995
# 2022-12-16  248.550003  249.839996  243.509995  244.690002  244.690002
# 2022-12-19  244.860001  245.210007  238.710007  240.449997  240.449997
#
#               Volume company_name company_fullname
# 2022-01-04  70726000         AMZN           AMAZON
# ...

# %%
#stock_info_easy.get_hist_data(['amazon', 'apple', 'microsoft', 'google'], start_date = '01/04/2022', end_date = '01/10/2022') # end_date is today's date by default.

# %%
stock_info_easy.get_closing_price_viz(company_list, comp_names)

# %%
stock_info_easy.get_daily_return_viz(company_list, comp_names)

# %%
stock_info_easy.predict_future_price(data_list, comp_names_abbr, \
                                     windown_size=30, predict_window_size=10)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_18 (LSTM)              (None, 30, 30)            3840
#
#  lstm_19 (LSTM)              (None, 64)                24320
#
#  dense_9 (Dense)             (None, 1)                 65
#
# ...
# Total params: 28,225
# Trainable params: 28,225
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 2022-12-20 21:25:33.247068: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 21:25:33.494210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 21:25:33.566416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ...
